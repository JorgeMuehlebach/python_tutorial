# %%
import pandas as pd


df1 = pd.read_excel('./data/MoreSFMCBriefFixes.xlsx')
df2 = pd.read_excel('./data/product_category_fixes.xlsx')

formatted = ""
count = 0
fixed_count = 0
for index, row in df1.iterrows():
    if str(row['Corrected Product Cat']) != 'nan' and row['Corrected Product Cat'] != 'NA':
        formatted += "('" + row['campaign_name'] + "', " + "'" + row['Corrected Product Cat'] + "'" + "),\n"


for index, row in df2.iterrows():
    if str(row['Corrected Product Category']) != 'nan' and str(row['Corrected Product Category']) != 'NA':
        formatted += "('" + row['campaign_name'] + "', " + "'" + row['Corrected Product Category'] + "'" + "),\n"

print(formatted)
# Out:
# ('SAL002_BINGE_3mth_offer_Sex_and_the_City_Feb_2022', 'Binge'),
# ('SAL002_BINGE3mthoffer_TheStaircaseMay2022_SVOD', 'Binge'),
# ('SAL002_BINGE_3mth_HarryPotter_Jan2022', 'Binge'),
# ('SAL002_BINGE_3mth_LOVEME_Dec2021', 'Binge'),
# ('SAL007_FLIP&FOLDXSELL_SAMSUNG', 'PostpaidMobileHandheld'),
# ('SAL002_Cross_Sell_FixedBlast_EDM', 'Fixed'),
# ('SAL002_BINGE_3mth_SATC_Dec2021', 'Binge'),
# ('SAL002_XsellApple13_CON_EDM_Pre-Order', 'PostpaidMobileHandheld'),
# ('SAL007_UpgradeApple13_CON_EDM_pre-order', 'PostpaidMobileHandheld'),
# ('SAL007_UpgradeApple13_CON_EDM_Launch', 'PostpaidMobileHandheld'),
# ('SAL002_XsellPixel6_CON_EDM_Launch', 'PostpaidMobileHandheld'),
# ('SAL002_XsellApple13_CON_EDM_Launch', 'PostpaidMobileHandheld'),
# ('SAL002_XsellPixel6_CON_EDM_pre-order', 'PostpaidMobileHandheld'),
# ('SAL007_TCAppleTradeIn_IOs', 'PostpaidMobileHandheld'),
# ('SAL007_UpgradeApple13_CON_EDM_Launch_resend', 'PostpaidMobileHandheld'),
# ...

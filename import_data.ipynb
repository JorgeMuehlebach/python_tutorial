# %% [markdown]
# ### In this notebook I will import a csv file and an excel file and do some basic manipulation

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/penguins.csv')
df
# Out:
#      Unnamed: 0 studyName  Sample Number  \
# 0             0   PAL0708              1
# 1             1   PAL0708              2
# 2             2   PAL0708              3
# 3             3   PAL0708              4
# 4             4   PAL0708              5
# ..          ...       ...            ...
# 339          63   PAL0910             64
# 340          64   PAL0910             65
# 341          65   PAL0910             66
# 342          66   PAL0910             67
# 343          67   PAL0910             68
#
#                                        Species  Region     Island  \
# 0          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                         ...     ...        ...
# ...

# %% [markdown]
# #### Read only one specific column

# %%
print(df.columns)
df['Sex']
# Out:
# Index(['Unnamed: 0', 'studyName', 'Sample Number', 'Species', 'Region',
#        'Island', 'Stage', 'Individual ID', 'Clutch Completion', 'Date Egg',
#        'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)',
#        'Comments'],
#       dtype='object')
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339      MALE
# 340    FEMALE
# 341      MALE
# 342      MALE
# 343    FEMALE
# Name: Sex, Length: 344, dtype: object

# %% [markdown]
# #### Drop columns

# %%
#df.drop(columns=['studyName', 'Sample Number', 'Region', 'Stage', 'Individual ID', 'Comments', df.columns[0]], inplace=True)
df_less_cols = df.drop(columns=['studyName', 'Sample Number', 'Region', 'Stage', 'Individual ID', 'Comments', df.columns[0]])
print(df_less_cols.columns)
df_less_cols
# Out:
# Index(['Species', 'Island', 'Clutch Completion', 'Date Egg',
#        'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
#        'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'],
#       dtype='object')
#                                        Species     Island Clutch Completion  \
# 0          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 1          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 2          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 3          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 4          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# ..                                         ...        ...               ...
# 339  Chinstrap penguin (Pygoscelis antarctica)      Dream               Yes
# 340  Chinstrap penguin (Pygoscelis antarctica)      Dream                No
# ...

# %% [markdown]
# #### Rename Columns

# %%
df_renamed_cols = df_less_cols.rename(columns={"Species":"Type", "Date Egg":"Date"})
df_renamed_cols
# Out:
#                                           Type     Island Clutch Completion  \
# 0          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 1          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 2          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 3          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# 4          Adelie Penguin (Pygoscelis adeliae)  Torgersen               Yes
# ..                                         ...        ...               ...
# 339  Chinstrap penguin (Pygoscelis antarctica)      Dream               Yes
# 340  Chinstrap penguin (Pygoscelis antarctica)      Dream                No
# 341  Chinstrap penguin (Pygoscelis antarctica)      Dream                No
# 342  Chinstrap penguin (Pygoscelis antarctica)      Dream               Yes
# 343  Chinstrap penguin (Pygoscelis antarctica)      Dream               Yes
#
# ...

# %% [markdown]
# #### Save the data/dataframe

# %%
df_renamed_cols.to_csv('./data/penguins_different_cols.csv')

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn import preprocessing
from datetime import datetime
import numpy as np

# %%
# Import 
penguins = pd.read_csv('./data/penguins.csv')
penguins
# Out:
#      Unnamed: 0 studyName  Sample Number  \
# 0             0   PAL0708              1
# 1             1   PAL0708              2
# 2             2   PAL0708              3
# 3             3   PAL0708              4
# 4             4   PAL0708              5
# ..          ...       ...            ...
# 339          63   PAL0910             64
# 340          64   PAL0910             65
# 341          65   PAL0910             66
# 342          66   PAL0910             67
# 343          67   PAL0910             68
#
#                                        Species  Region     Island  \
# 0          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                         ...     ...        ...
# 339  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 340  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 341  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 342  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 343  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
#
#                   Stage Individual ID Clutch Completion    Date Egg  \
# 0    Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1    Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2    Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3    Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4    Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
# ..                  ...           ...               ...         ...
# 339  Adult, 1 Egg Stage         N98A2               Yes  2009-11-19
# 340  Adult, 1 Egg Stage         N99A1                No  2009-11-21
# 341  Adult, 1 Egg Stage         N99A2                No  2009-11-21
# 342  Adult, 1 Egg Stage        N100A1               Yes  2009-11-21
# 343  Adult, 1 Egg Stage        N100A2               Yes  2009-11-21
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0                  39.1               18.7                181.0
# 1                  39.5               17.4                186.0
# 2                  40.3               18.0                195.0
# 3                   NaN                NaN                  NaN
# 4                  36.7               19.3                193.0
# ..                  ...                ...                  ...
# 339                55.8               19.8                207.0
# 340                43.5               18.1                202.0
# 341                49.6               18.2                193.0
# 342                50.8               19.0                210.0
# 343                50.2               18.7                198.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0           3750.0    MALE                NaN                NaN
# 1           3800.0  FEMALE            8.94956          -24.69454
# 2           3250.0  FEMALE            8.36821          -25.33302
# 3              NaN     NaN                NaN                NaN
# 4           3450.0  FEMALE            8.76651          -25.32426
# ..             ...     ...                ...                ...
# 339         4000.0    MALE            9.70465          -24.53494
# 340         3400.0  FEMALE            9.37608          -24.40753
# 341         3775.0    MALE            9.46180          -24.70615
# 342         4100.0    MALE            9.98044          -24.68741
# 343         3775.0  FEMALE            9.39305          -24.25255
#
#                                   Comments
# 0           Not enough blood for isotopes.
# 1                                      NaN
# 2                                      NaN
# 3                       Adult not sampled.
# 4                                      NaN
# ..                                     ...
# 339                                    NaN
# 340  Nest never observed with full clutch.
# 341  Nest never observed with full clutch.
# 342                                    NaN
# 343                                    NaN
#
# [344 rows x 18 columns]

# %%
penguins_shuffled = penguins.sample(frac = 1)
penguins_shuffled
# Out:
#      Unnamed: 0 studyName  Sample Number  \
# 148         148   PAL0910            149
# 16           16   PAL0708             17
# 224          72   PAL0809             73
# 57           57   PAL0809             58
# 130         130   PAL0910            131
# ..          ...       ...            ...
# 335          59   PAL0910             60
# 3             3   PAL0708              4
# 99           99   PAL0809            100
# 4             4   PAL0708              5
# 121         121   PAL0910            122
#
#                                        Species  Region     Island  \
# 148        Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 16         Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 224          Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 57         Adelie Penguin (Pygoscelis adeliae)  Anvers     Biscoe
# 130        Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                         ...     ...        ...
# 335  Chinstrap penguin (Pygoscelis antarctica)  Anvers      Dream
# 3          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 99         Adelie Penguin (Pygoscelis adeliae)  Anvers      Dream
# 4          Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 121        Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                   Stage Individual ID Clutch Completion    Date Egg  \
# 148  Adult, 1 Egg Stage         N84A1               Yes  2009-11-17
# 16   Adult, 1 Egg Stage          N9A1               Yes  2007-11-12
# 224  Adult, 1 Egg Stage         N55A1               Yes  2008-11-09
# 57   Adult, 1 Egg Stage         N24A2               Yes  2008-11-15
# 130  Adult, 1 Egg Stage         N73A1                No  2009-11-23
# ..                  ...           ...               ...         ...
# 335  Adult, 1 Egg Stage         N95A2               Yes  2009-11-21
# 3    Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 99   Adult, 1 Egg Stage         N50A2               Yes  2008-11-10
# 4    Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
# 121  Adult, 1 Egg Stage         N66A2                No  2009-11-17
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 148                36.0               17.8                195.0
# 16                 38.7               19.0                195.0
# 224                48.2               15.6                221.0
# 57                 40.6               18.8                193.0
# 130                38.5               17.9                190.0
# ..                  ...                ...                  ...
# 335                45.6               19.4                194.0
# 3                   NaN                NaN                  NaN
# 99                 43.2               18.5                192.0
# 4                  36.7               19.3                193.0
# 121                37.7               19.8                198.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 148         3450.0  FEMALE            8.94332          -25.79189
# 16          3450.0  FEMALE            9.18528          -25.06691
# 224         5100.0    MALE            8.24651          -26.66958
# 57          3800.0    MALE            8.56674          -25.98843
# 130         3325.0  FEMALE            8.98460          -25.57956
# ..             ...     ...                ...                ...
# 335         3525.0  FEMALE            9.46985          -24.65786
# 3              NaN     NaN                NaN                NaN
# 99          4100.0    MALE            8.97025          -26.03679
# 4           3450.0  FEMALE            8.76651          -25.32426
# 121         3500.0    MALE            9.11066          -26.42563
#
#                                   Comments
# 148                                    NaN
# 16                                     NaN
# 224                                    NaN
# 57                                     NaN
# 130  Nest never observed with full clutch.
# ..                                     ...
# 335                                    NaN
# 3                       Adult not sampled.
# 99                                     NaN
# 4                                      NaN
# 121  Nest never observed with full clutch.
#
# [344 rows x 18 columns]

# %%
# CONVERTING CLASSES TO INTEGER VALUES
class_types = ['Sex', 'Species', 'Island', 'Clutch Completion']
labelEncoder = preprocessing.LabelEncoder()
for ct in class_types:
    penguins[ct] = labelEncoder.fit_transform(penguins[ct])
